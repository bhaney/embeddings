# %%
# Relational-GCN as implemented by M. Schlichtkrull, T. N. Kipf, P. Bloem, R. van den Berg, I. Titov, M. Welling, 
# in Modeling Relational Data with Graph Convolutional Networks, 2017
import numpy as np
from multigraph import MultiGraph
import unicodecsv as csv

# %%
#import csv
""" EXAMPLE
add,IS,operator
subtract,IS,operator
multiply,IS,operator
divide,IS,operator
open_closure,IS,operator
close_closure,IS,operator
"""
op_graph = MultiGraph()
#with open('operator_graph.csv', 'r') as csvfile:
n = 45
for i in range(n):
    print '.',
    with open('aifb_csv/aifb_relation_'+str(i)+'.csv', 'r') as csvfile:
        graphreader = csv.reader(csvfile, delimiter=",")
        for row in graphreader:
            op_graph.add_connection(row)
print('\n loaded '+str(op_graph.n_rels)+' relations.')

import pickle
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

#save the adjacency matrix as well
save_object(op_graph, 'adj_graph.pkl')
print("Saved graph object to disk")

# %%
import pickle
with open('adj_graph.pkl', 'rb') as inobj:
    op_graph = pickle.load(inobj)

# %%
num_nodes = op_graph.n_nodes
num_relations = op_graph.n_rels

# %%
import scipy.sparse as sp
# Create list of adjacency matrices, transpose, and identity
A = list()
for i in range(num_relations):
    k = op_graph.get_relation_label(i)
    A.append(op_graph.get_adjacency_matrix_k(k))
    A.append(op_graph.get_transpose_adjacency_matrix_k(k))
A.append(sp.identity(num_nodes).tocsr())
support = len(A)

# Normalize adjacency matrices
for i in range(len(A)):
    d = np.array(A[i].sum(1)).flatten()
    d_inv = 1. / d
    d_inv[np.isinf(d_inv)] = 0.
    D_inv = sp.diags(d_inv)
    A[i] = D_inv.dot(A[i]).tocsr()
    
X = sp.csr_matrix(A[0].shape)
# Out:
# /usr/local/anaconda3/envs/embeddings/lib/python2.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in divide

# %%
import random
from collections import defaultdict
# Get targets for training and testing. 
def get_train_test_labels(graph, filename, train_frac=0.8):
    training_dict = defaultdict(list)
    train_ids = list()
    test_ids = list()
    with open(filename, 'r') as csvfile:
        graphreader = csv.reader(csvfile)
        i = 0 #first row is the header, skip it
        for row in graphreader:
            if i == 0:
                i += 1
                continue
            #replace name of node with node index in the graph
            idx = graph.nodes[row[0]]
            training_dict[row[1]].append(idx)
            #randomly sort sample into the training or test set
            if random.random() < train_frac:
                train_ids.append(idx)
            else:
                test_ids.append(idx)
    num_labels = len(training_dict.keys())
    #create a sparse matrix with all the nodes that have labels
    labels = sp.lil_matrix((num_nodes, num_labels))
    i = 0
    for k,v in training_dict.iteritems():   
        for s in v:
            labels[s, i] = 1
        i += 1
    return (labels, train_ids, test_ids)

# %%
from rgcn.utils import *
#get train, validation, and testing sets
VALIDATION = True

y, train_idx, test_idx = get_train_test_labels(op_graph, 'aifb_csv/completeDataset.csv', train_frac=0.8)
y_train, y_val, y_test, idx_train, idx_val, idx_test = get_splits(y, train_idx, test_idx,VALIDATION)

train_mask = sample_mask(idx_train, y.shape[0])

# %%
import keras
from keras.layers import Input, Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.regularizers import l2

from rgcn.layers.graph import GraphConvolution
from rgcn.layers.input_adj import InputAdj

encoding_dim = 16
L2 = 0.0
LR = 0.01
DO = 0.0

# Define empty dummy feature matrix (input is ignored as we set featureless=True)
# In case features are available, define them here and set featureless=False.
A_in = [InputAdj(sparse=True) for _ in range(support)]
X_in = Input(shape=(X.shape[1],), sparse=True)

# Define model architecture
ConvLayer1 = GraphConvolution(encoding_dim, support=support, num_bases=-1, use_bias=False, featureless=True, activation='relu', kernel_regularizer=l2(L2))
DropOutLayer = Dropout(DO)
ConvLayer2 = GraphConvolution(y_train.shape[1], support=support, use_bias=False, featureless=False, num_bases=-1, activation='softmax')

the_code = ConvLayer1([X_in] + A_in)
H = DropOutLayer(the_code)
Y = ConvLayer2([H] + A_in)

# Compile model
model = Model(inputs=[X_in] + A_in, outputs=Y)
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=LR))
model.summary()
# Out:
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_92 (InputLayer)           (None, 8284)         0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_25 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_32 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_33 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_34 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_35 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_36 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_37 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_38 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_39 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_40 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_41 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_42 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_43 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_44 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_45 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_46 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_47 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_48 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_49 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_50 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_51 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_52 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_53 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_54 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_55 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_56 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_57 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_58 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_59 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_60 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_61 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_62 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_63 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_64 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_65 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_66 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_67 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_68 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_69 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_70 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_71 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_72 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_73 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_74 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_75 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_76 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_77 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_78 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_79 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_80 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_81 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_82 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_83 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_84 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_85 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_86 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_87 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_88 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_89 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_90 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# input_91 (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# graph_convolution_1 (GraphConvo (None, 16)           12061504    input_92[0][0]
#                                                                  input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
#                                                                  input_10[0][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
#                                                                  input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
#                                                                  input_17[0][0]
#                                                                  input_18[0][0]
#                                                                  input_19[0][0]
#                                                                  input_20[0][0]
#                                                                  input_21[0][0]
#                                                                  input_22[0][0]
#                                                                  input_23[0][0]
#                                                                  input_24[0][0]
#                                                                  input_25[0][0]
#                                                                  input_26[0][0]
#                                                                  input_27[0][0]
#                                                                  input_28[0][0]
#                                                                  input_29[0][0]
#                                                                  input_30[0][0]
#                                                                  input_31[0][0]
#                                                                  input_32[0][0]
#                                                                  input_33[0][0]
#                                                                  input_34[0][0]
#                                                                  input_35[0][0]
#                                                                  input_36[0][0]
#                                                                  input_37[0][0]
#                                                                  input_38[0][0]
#                                                                  input_39[0][0]
#                                                                  input_40[0][0]
#                                                                  input_41[0][0]
#                                                                  input_42[0][0]
#                                                                  input_43[0][0]
#                                                                  input_44[0][0]
#                                                                  input_45[0][0]
#                                                                  input_46[0][0]
#                                                                  input_47[0][0]
#                                                                  input_48[0][0]
#                                                                  input_49[0][0]
#                                                                  input_50[0][0]
#                                                                  input_51[0][0]
#                                                                  input_52[0][0]
#                                                                  input_53[0][0]
#                                                                  input_54[0][0]
#                                                                  input_55[0][0]
#                                                                  input_56[0][0]
#                                                                  input_57[0][0]
#                                                                  input_58[0][0]
#                                                                  input_59[0][0]
#                                                                  input_60[0][0]
#                                                                  input_61[0][0]
#                                                                  input_62[0][0]
#                                                                  input_63[0][0]
#                                                                  input_64[0][0]
#                                                                  input_65[0][0]
#                                                                  input_66[0][0]
#                                                                  input_67[0][0]
#                                                                  input_68[0][0]
#                                                                  input_69[0][0]
#                                                                  input_70[0][0]
#                                                                  input_71[0][0]
#                                                                  input_72[0][0]
#                                                                  input_73[0][0]
#                                                                  input_74[0][0]
#                                                                  input_75[0][0]
#                                                                  input_76[0][0]
#                                                                  input_77[0][0]
#                                                                  input_78[0][0]
#                                                                  input_79[0][0]
#                                                                  input_80[0][0]
#                                                                  input_81[0][0]
#                                                                  input_82[0][0]
#                                                                  input_83[0][0]
#                                                                  input_84[0][0]
#                                                                  input_85[0][0]
#                                                                  input_86[0][0]
#                                                                  input_87[0][0]
#                                                                  input_88[0][0]
#                                                                  input_89[0][0]
#                                                                  input_90[0][0]
#                                                                  input_91[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           graph_convolution_1[0][0]
# __________________________________________________________________________________________________
# graph_convolution_2 (GraphConvo (None, 4)            5824        dropout_1[0][0]
#                                                                  input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
#                                                                  input_10[0][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
#                                                                  input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
#                                                                  input_17[0][0]
#                                                                  input_18[0][0]
#                                                                  input_19[0][0]
#                                                                  input_20[0][0]
#                                                                  input_21[0][0]
#                                                                  input_22[0][0]
#                                                                  input_23[0][0]
#                                                                  input_24[0][0]
#                                                                  input_25[0][0]
#                                                                  input_26[0][0]
#                                                                  input_27[0][0]
#                                                                  input_28[0][0]
#                                                                  input_29[0][0]
#                                                                  input_30[0][0]
#                                                                  input_31[0][0]
#                                                                  input_32[0][0]
#                                                                  input_33[0][0]
#                                                                  input_34[0][0]
#                                                                  input_35[0][0]
#                                                                  input_36[0][0]
#                                                                  input_37[0][0]
#                                                                  input_38[0][0]
#                                                                  input_39[0][0]
#                                                                  input_40[0][0]
#                                                                  input_41[0][0]
#                                                                  input_42[0][0]
#                                                                  input_43[0][0]
#                                                                  input_44[0][0]
#                                                                  input_45[0][0]
#                                                                  input_46[0][0]
#                                                                  input_47[0][0]
#                                                                  input_48[0][0]
#                                                                  input_49[0][0]
#                                                                  input_50[0][0]
#                                                                  input_51[0][0]
#                                                                  input_52[0][0]
#                                                                  input_53[0][0]
#                                                                  input_54[0][0]
#                                                                  input_55[0][0]
#                                                                  input_56[0][0]
#                                                                  input_57[0][0]
#                                                                  input_58[0][0]
#                                                                  input_59[0][0]
#                                                                  input_60[0][0]
#                                                                  input_61[0][0]
#                                                                  input_62[0][0]
#                                                                  input_63[0][0]
#                                                                  input_64[0][0]
#                                                                  input_65[0][0]
#                                                                  input_66[0][0]
#                                                                  input_67[0][0]
#                                                                  input_68[0][0]
#                                                                  input_69[0][0]
#                                                                  input_70[0][0]
#                                                                  input_71[0][0]
#                                                                  input_72[0][0]
#                                                                  input_73[0][0]
#                                                                  input_74[0][0]
#                                                                  input_75[0][0]
#                                                                  input_76[0][0]
#                                                                  input_77[0][0]
#                                                                  input_78[0][0]
#                                                                  input_79[0][0]
#                                                                  input_80[0][0]
#                                                                  input_81[0][0]
#                                                                  input_82[0][0]
#                                                                  input_83[0][0]
#                                                                  input_84[0][0]
#                                                                  input_85[0][0]
#                                                                  input_86[0][0]
#                                                                  input_87[0][0]
#                                                                  input_88[0][0]
#                                                                  input_89[0][0]
#                                                                  input_90[0][0]
#                                                                  input_91[0][0]
# ==================================================================================================
# Total params: 12,067,328
# Trainable params: 12,067,328
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print('number of nodes',num_nodes)
print('number of relations',num_relations)
# Out:
# ('number of nodes', 8284)
# ('number of relations', 45)

# %%
import time
preds = None
NB_EPOCH = 50
# Fit
for ep in range(1, NB_EPOCH + 1):
    # Log wall-clock time
    t = time.time()
    # Single training iteration
    model.fit([X] + A, y=y_train, batch_size=num_nodes, sample_weight=train_mask, epochs=1, shuffle=False, verbose=0)
    #model.fit([X] + A, y_train, sample_weight=train_mask,
    #          batch_size=num_nodes, epochs=1, shuffle=False, verbose=1)
    if ep % 1 == 0:
        # Predict on full dataset
        preds = model.predict([X] + A, batch_size=num_nodes)
        # Train / validation scores
        train_val_loss, train_val_acc = evaluate_preds(preds, [y_train, y_val],
                                                       [idx_train, idx_val])
        print("Epoch: {:04d}".format(ep),
              "train_loss= {:.4f}".format(train_val_loss[0]),
              "train_acc= {:.4f}".format(train_val_acc[0]),
              "val_loss= {:.4f}".format(train_val_loss[1]),
              "val_acc= {:.4f}".format(train_val_acc[1]),
              "time= {:.4f}".format(time.time() - t))

    else:
        print("Epoch: {:04d}".format(ep),
              "time= {:.4f}".format(time.time() - t))
# Out:
# ('Epoch: 0001', 'train_loss= 1.3217', 'train_acc= 0.9196', 'val_loss= 1.3347', 'val_acc= 0.9643', 'time= 5.7927')
# ('Epoch: 0002', 'train_loss= 1.2109', 'train_acc= 0.9196', 'val_loss= 1.2452', 'val_acc= 0.9643', 'time= 1.0161')
# ('Epoch: 0003', 'train_loss= 1.0579', 'train_acc= 0.9196', 'val_loss= 1.1182', 'val_acc= 0.9643', 'time= 0.9053')
# ('Epoch: 0004', 'train_loss= 0.8904', 'train_acc= 0.9107', 'val_loss= 0.9723', 'val_acc= 1.0000', 'time= 1.0042')
# ('Epoch: 0005', 'train_loss= 0.7106', 'train_acc= 0.9286', 'val_loss= 0.8036', 'val_acc= 1.0000', 'time= 0.8632')
# ('Epoch: 0006', 'train_loss= 0.5493', 'train_acc= 0.9286', 'val_loss= 0.6377', 'val_acc= 1.0000', 'time= 0.8651')
# ('Epoch: 0007', 'train_loss= 0.4173', 'train_acc= 0.9464', 'val_loss= 0.4892', 'val_acc= 1.0000', 'time= 0.8672')
# ('Epoch: 0008', 'train_loss= 0.3115', 'train_acc= 0.9554', 'val_loss= 0.3592', 'val_acc= 1.0000', 'time= 0.8735')
# ('Epoch: 0009', 'train_loss= 0.2343', 'train_acc= 0.9554', 'val_loss= 0.2562', 'val_acc= 1.0000', 'time= 0.8656')
# ('Epoch: 0010', 'train_loss= 0.1808', 'train_acc= 0.9554', 'val_loss= 0.1813', 'val_acc= 1.0000', 'time= 0.8833')
# ('Epoch: 0011', 'train_loss= 0.1445', 'train_acc= 0.9554', 'val_loss= 0.1307', 'val_acc= 1.0000', 'time= 0.8542')
# ('Epoch: 0012', 'train_loss= 0.1191', 'train_acc= 0.9732', 'val_loss= 0.0983', 'val_acc= 1.0000', 'time= 0.8793')
# ('Epoch: 0013', 'train_loss= 0.0999', 'train_acc= 0.9732', 'val_loss= 0.0782', 'val_acc= 1.0000', 'time= 0.8698')
# ('Epoch: 0014', 'train_loss= 0.0841', 'train_acc= 0.9732', 'val_loss= 0.0662', 'val_acc= 1.0000', 'time= 0.8869')
# ('Epoch: 0015', 'train_loss= 0.0706', 'train_acc= 0.9732', 'val_loss= 0.0595', 'val_acc= 1.0000', 'time= 0.9627')
# ('Epoch: 0016', 'train_loss= 0.0589', 'train_acc= 0.9732', 'val_loss= 0.0567', 'val_acc= 1.0000', 'time= 0.8631')
# ('Epoch: 0017', 'train_loss= 0.0490', 'train_acc= 0.9821', 'val_loss= 0.0566', 'val_acc= 1.0000', 'time= 0.8712')
# ('Epoch: 0018', 'train_loss= 0.0407', 'train_acc= 0.9821', 'val_loss= 0.0587', 'val_acc= 1.0000', 'time= 0.8677')
# ('Epoch: 0019', 'train_loss= 0.0340', 'train_acc= 0.9821', 'val_loss= 0.0624', 'val_acc= 1.0000', 'time= 0.8709')
# ('Epoch: 0020', 'train_loss= 0.0287', 'train_acc= 0.9911', 'val_loss= 0.0672', 'val_acc= 1.0000', 'time= 0.8692')
# ('Epoch: 0021', 'train_loss= 0.0246', 'train_acc= 1.0000', 'val_loss= 0.0725', 'val_acc= 1.0000', 'time= 0.8763')
# ('Epoch: 0022', 'train_loss= 0.0214', 'train_acc= 1.0000', 'val_loss= 0.0775', 'val_acc= 1.0000', 'time= 0.8826')
# ('Epoch: 0023', 'train_loss= 0.0188', 'train_acc= 1.0000', 'val_loss= 0.0815', 'val_acc= 1.0000', 'time= 0.8696')
# ('Epoch: 0024', 'train_loss= 0.0165', 'train_acc= 1.0000', 'val_loss= 0.0842', 'val_acc= 1.0000', 'time= 0.8786')
# ('Epoch: 0025', 'train_loss= 0.0143', 'train_acc= 1.0000', 'val_loss= 0.0851', 'val_acc= 1.0000', 'time= 0.9048')
# ('Epoch: 0026', 'train_loss= 0.0124', 'train_acc= 1.0000', 'val_loss= 0.0844', 'val_acc= 1.0000', 'time= 0.8950')
# ('Epoch: 0027', 'train_loss= 0.0107', 'train_acc= 1.0000', 'val_loss= 0.0824', 'val_acc= 1.0000', 'time= 0.9078')
# ('Epoch: 0028', 'train_loss= 0.0091', 'train_acc= 1.0000', 'val_loss= 0.0792', 'val_acc= 1.0000', 'time= 0.8930')
# ('Epoch: 0029', 'train_loss= 0.0077', 'train_acc= 1.0000', 'val_loss= 0.0754', 'val_acc= 1.0000', 'time= 0.8580')
# ('Epoch: 0030', 'train_loss= 0.0065', 'train_acc= 1.0000', 'val_loss= 0.0711', 'val_acc= 1.0000', 'time= 0.8800')
# ('Epoch: 0031', 'train_loss= 0.0055', 'train_acc= 1.0000', 'val_loss= 0.0667', 'val_acc= 1.0000', 'time= 0.8589')
# ('Epoch: 0032', 'train_loss= 0.0047', 'train_acc= 1.0000', 'val_loss= 0.0624', 'val_acc= 1.0000', 'time= 0.8718')
# ('Epoch: 0033', 'train_loss= 0.0041', 'train_acc= 1.0000', 'val_loss= 0.0582', 'val_acc= 1.0000', 'time= 0.8622')
# ('Epoch: 0034', 'train_loss= 0.0035', 'train_acc= 1.0000', 'val_loss= 0.0545', 'val_acc= 1.0000', 'time= 0.8779')
# ('Epoch: 0035', 'train_loss= 0.0031', 'train_acc= 1.0000', 'val_loss= 0.0510', 'val_acc= 1.0000', 'time= 0.8684')
# ('Epoch: 0036', 'train_loss= 0.0028', 'train_acc= 1.0000', 'val_loss= 0.0479', 'val_acc= 1.0000', 'time= 1.1339')
# ('Epoch: 0037', 'train_loss= 0.0025', 'train_acc= 1.0000', 'val_loss= 0.0452', 'val_acc= 1.0000', 'time= 0.8615')
# ('Epoch: 0038', 'train_loss= 0.0022', 'train_acc= 1.0000', 'val_loss= 0.0428', 'val_acc= 1.0000', 'time= 0.8736')
# ('Epoch: 0039', 'train_loss= 0.0020', 'train_acc= 1.0000', 'val_loss= 0.0407', 'val_acc= 1.0000', 'time= 0.8759')
# ('Epoch: 0040', 'train_loss= 0.0018', 'train_acc= 1.0000', 'val_loss= 0.0389', 'val_acc= 1.0000', 'time= 0.9013')
# ('Epoch: 0041', 'train_loss= 0.0016', 'train_acc= 1.0000', 'val_loss= 0.0373', 'val_acc= 1.0000', 'time= 0.8703')
# ('Epoch: 0042', 'train_loss= 0.0015', 'train_acc= 1.0000', 'val_loss= 0.0359', 'val_acc= 1.0000', 'time= 0.8821')
# ('Epoch: 0043', 'train_loss= 0.0014', 'train_acc= 1.0000', 'val_loss= 0.0348', 'val_acc= 1.0000', 'time= 0.9136')
# ('Epoch: 0044', 'train_loss= 0.0013', 'train_acc= 1.0000', 'val_loss= 0.0338', 'val_acc= 1.0000', 'time= 0.9145')
# ('Epoch: 0045', 'train_loss= 0.0012', 'train_acc= 1.0000', 'val_loss= 0.0329', 'val_acc= 1.0000', 'time= 1.1389')
# ('Epoch: 0046', 'train_loss= 0.0011', 'train_acc= 1.0000', 'val_loss= 0.0322', 'val_acc= 1.0000', 'time= 1.2055')
# ('Epoch: 0047', 'train_loss= 0.0010', 'train_acc= 1.0000', 'val_loss= 0.0316', 'val_acc= 1.0000', 'time= 0.9258')
# ('Epoch: 0048', 'train_loss= 0.0010', 'train_acc= 1.0000', 'val_loss= 0.0311', 'val_acc= 1.0000', 'time= 0.8921')
# ('Epoch: 0049', 'train_loss= 0.0009', 'train_acc= 1.0000', 'val_loss= 0.0307', 'val_acc= 1.0000', 'time= 0.8879')
# ('Epoch: 0050', 'train_loss= 0.0009', 'train_acc= 1.0000', 'val_loss= 0.0304', 'val_acc= 1.0000', 'time= 0.8803')

# %%
# Testing
test_loss, test_acc = evaluate_preds(preds, [y_test], [idx_test])
print("Test set results:",
      "loss= {:.4f}".format(test_loss[0]),
      "accuracy= {:.4f}".format(test_acc[0]))
# Out:
# ('Test set results:', 'loss= 0.0304', 'accuracy= 1.0000')

# %%
coding_model = Model(inputs=[X_in] + A_in, outputs=the_code)
embedding = coding_model.predict([X] + A, batch_size=num_nodes)

# %%
#save the embeddings in order to plot them later
# serialize model to JSON
model_json = coding_model.to_json()
with open("rgcn_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
coding_model.save_weights("rgcn_model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
import pickle
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

#save the adjacency matrix as well
save_object(op_graph, 'adj_graph.pkl')
print("Saved graph object to disk")
